# %%
import requests
import json
import urllib3


# Proxmox API Credentials
PROXMOX_HOST = "192.168.0.100"
USERNAME = "root@pam"  # Root user (or API user)
PASSWORD = "password"
NODE = "proxmox"

# Thresholds
CPU_THRESHOLD = 80  # % usage
RAM_THRESHOLD = 80  # % usage

# Disable SSL warnings
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# Authenticate and get ticket/token
def get_proxmox_ticket():
    url = f"https://{PROXMOX_HOST}:8006/api2/json/access/ticket"
    payload = {"username": USERNAME, "password": PASSWORD}
    headers = {"Content-Type": "application/x-www-form-urlencoded"}

    response = requests.post(url, data=payload, headers=headers, verify=False)

    if response.status_code == 200:
        data = response.json()
        return data["data"]["ticket"], data["data"]["CSRFPreventionToken"]
    else:
        print(f"❌ Failed to authenticate: {response.text}")
        return None, None

# Get VM usage stats
def get_vm_usage(vm_id, ticket):
    url = f"https://{PROXMOX_HOST}:8006/api2/json/nodes/{NODE}/qemu/{vm_id}/status/current"
    headers = {"Cookie": f"PVEAuthCookie={ticket}"}

    response = requests.get(url, headers=headers, verify=False)

    if response.status_code == 200:
        data = response.json()
        if "data" in data:
            print("✅ API Response:", json.dumps(data["data"], indent=4))  # Print full response
            return data["data"]
        else:
            print(f"❌ No usage data found for VM {vm_id}.")
            print("🔍 API Response:", response.text)
            return None
    else:
        print(f"❌ Failed to fetch usage for VM {vm_id}. HTTP Status: {response.status_code}")
        print("🔍 Response:", response.text)
        return None

# Main script execution
ticket, csrf_token = get_proxmox_ticket()
if ticket:
    vm_data = get_vm_usage(100, ticket)
    if vm_data:
        print("✅ Successfully retrieved VM usage stats!")


def get_vms(ticket):
    # Get the list of Proxmox nodes first
    nodes_url = f"https://{PROXMOX_HOST}:8006/api2/json/nodes"
    headers = {"Cookie": f"PVEAuthCookie={ticket}"}

    nodes_response = requests.get(nodes_url, headers=headers, verify=False)
    if nodes_response.status_code == 200:
        nodes_data = nodes_response.json()
        if "data" in nodes_data and nodes_data["data"]:
            node_name = nodes_data["data"][0]["node"]  # Get the first available node
            print(f"✅ Using node: {node_name}")  # Print selected node
            
            # Now, get the VMs for that node
            url = f"https://{PROXMOX_HOST}:8006/api2/json/nodes/{node_name}/qemu"
            response = requests.get(url, headers=headers, verify=False)

            if response.status_code == 200:
                data = response.json()
                if "data" in data:
                    return data["data"]
                else:
                    print("❌ No VMs found on the node.")
                    return []
            else:
                print(f"❌ Failed to fetch VM list. HTTP Status: {response.status_code}")
                print("🔍 Response:", response.text)  # Print full response for debugging
                return []
        else:
            print("❌ No nodes found in Proxmox.")
            return []
    else:
        print(f"❌ Failed to fetch Proxmox nodes. HTTP Status: {nodes_response.status_code}")
        print("🔍 Response:", nodes_response.text)  # Print full response for debugging
        return []

# Scale VM if needed
def scale_vm(vm_id, vm_name, cpu, max_cpu, ram, max_ram, ticket, csrf_token):
    if cpu > CPU_THRESHOLD:
        new_cpus = min(max_cpu + 1, 8)  # Limit to 8 CPUs max
        print(f"⚡ Scaling up CPU for VM {vm_name} ({vm_id}) to {new_cpus} CPUs...")
        scale_url = f"https://{PROXMOX_HOST}:8006/api2/json/nodes/{NODE}/qemu/{vm_id}/config"
        headers = {"Cookie": f"PVEAuthCookie={ticket}", "CSRFPreventionToken": csrf_token}
        payload = {"cores": new_cpus}
        requests.put(scale_url, headers=headers, data=payload, verify=False)

    if ram > RAM_THRESHOLD:
        new_ram = min(max_ram + 1024, 8192)  # Limit to 8GB max
        print(f"⚡ Scaling up RAM for VM {vm_name} ({vm_id}) to {new_ram} MB...")
        scale_url = f"https://{PROXMOX_HOST}:8006/api2/json/nodes/{NODE}/qemu/{vm_id}/config"
        headers = {"Cookie": f"PVEAuthCookie={ticket}", "CSRFPreventionToken": csrf_token}
        payload = {"memory": new_ram}
        requests.put(scale_url, headers=headers, data=payload, verify=False)

# Main script execution
if __name__ == "__main__":
    ticket, csrf_token = get_proxmox_ticket()
    vms = get_vms(ticket)

    for vm in vms:
        vm_id = vm["vmid"]
        vm_name = vm["name"]
        stats = get_vm_usage(vm_id, ticket)

        if stats:
            cpu_usage = stats["cpu"] * 100  # Convert to percentage
            ram_usage = (stats["mem"] / stats["maxmem"]) * 100  # Convert to percentage

            print(f"🔍 VM: {vm_name} | CPU: {cpu_usage:.2f}% | RAM: {ram_usage:.2f}%")

            #scale_vm(vm_id, vm_name, cpu_usage, vm["cores"], ram_usage, vm["maxmem"] // 1024, ticket, csrf_token)
            scale_vm(vm_id, vm_name, cpu_usage, stats["cpus"], ram_usage, stats["maxmem"] // 1024, ticket, csrf_token)


    print("✅ Scaling check complete.")
# Out:
# ✅ API Response: {
#     "qmpstatus": "running",
#     "maxmem": 4294967296,
#     "pid": 104400,
#     "uptime": 3368,
#     "status": "running",
#     "cpus": 2,
#     "name": "rhel8-vm",
#     "serial": 1,
#     "running-qemu": "9.0.2",
#     "vmid": 100,
#     "freemem": 3198337024,
#     "disk": 0,
#     "running-machine": "pc-q35-9.0+pve0",
#     "proxmox-support": {
#         "backup-fleecing": true,
#         "pbs-library-version": "1.4.1 (UNKNOWN)",
#         "pbs-dirty-bitmap-migration": true,
#         "pbs-dirty-bitmap-savevm": true,
#         "pbs-masterkey": true,
#         "backup-max-workers": true,
#         "pbs-dirty-bitmap": true,
#         "query-bitmap-info": true
#     },
#     "cpu": 0.00786088747202273,
#     "netout": 137727,
#     "blockstat": {
#         "pflash0": {
#             "rd_operations": 0,
#             "wr_merged": 0,
#             "flush_total_time_ns": 0,
#             "invalid_wr_operations": 0,
#             "rd_total_time_ns": 0,
#             "account_invalid": true,
#             "failed_zone_append_operations": 0,
#             "wr_highest_offset": 0,
#             "rd_bytes": 0,
#             "failed_flush_operations": 0,
#             "zone_append_total_time_ns": 0,
#             "failed_unmap_operations": 0,
#             "invalid_flush_operations": 0,
#             "zone_append_bytes": 0,
#             "failed_wr_operations": 0,
#             "invalid_unmap_operations": 0,
#             "unmap_total_time_ns": 0,
#             "timed_stats": [],
#             "unmap_merged": 0,
#             "invalid_rd_operations": 0,
#             "failed_rd_operations": 0,
#             "zone_append_operations": 0,
#             "invalid_zone_append_operations": 0,
#             "unmap_operations": 0,
#             "flush_operations": 0,
#             "wr_total_time_ns": 0,
#             "account_failed": true,
#             "unmap_bytes": 0,
#             "zone_append_merged": 0,
#             "wr_bytes": 0,
#             "wr_operations": 0,
#             "rd_merged": 0
#         },
#         "ide2": {
#             "flush_operations": 0,
#             "wr_total_time_ns": 0,
#             "account_failed": true,
#             "zone_append_merged": 0,
#             "wr_bytes": 0,
#             "unmap_bytes": 0,
#             "wr_operations": 0,
#             "rd_merged": 0,
#             "unmap_merged": 0,
#             "zone_append_operations": 0,
#             "invalid_zone_append_operations": 0,
#             "unmap_operations": 0,
#             "failed_rd_operations": 0,
#             "invalid_rd_operations": 0,
#             "zone_append_bytes": 0,
#             "invalid_flush_operations": 0,
#             "failed_unmap_operations": 0,
#             "idle_time_ns": 3352849219650,
#             "failed_wr_operations": 0,
#             "invalid_unmap_operations": 0,
#             "unmap_total_time_ns": 0,
#             "timed_stats": [],
#             "rd_operations": 86,
#             "flush_total_time_ns": 0,
#             "invalid_wr_operations": 0,
#             "wr_merged": 0,
#             "failed_zone_append_operations": 0,
#             "wr_highest_offset": 0,
#             "account_invalid": true,
#             "rd_total_time_ns": 3211717,
#             "failed_flush_operations": 0,
#             "zone_append_total_time_ns": 0,
#             "rd_bytes": 2187528
#         },
#         "efidisk0": {
#             "invalid_unmap_operations": 0,
#             "timed_stats": [],
#             "unmap_total_time_ns": 0,
#             "failed_unmap_operations": 0,
#             "zone_append_bytes": 0,
#             "invalid_flush_operations": 0,
#             "failed_wr_operations": 0,
#             "rd_total_time_ns": 0,
#             "account_invalid": true,
#             "wr_highest_offset": 49152,
#             "failed_zone_append_operations": 0,
#             "rd_bytes": 0,
#             "zone_append_total_time_ns": 0,
#             "failed_flush_operations": 0,
#             "rd_operations": 0,
#             "wr_merged": 0,
#             "invalid_wr_operations": 0,
#             "flush_total_time_ns": 0,
#             "wr_operations": 0,
#             "rd_merged": 0,
#             "wr_total_time_ns": 0,
#             "account_failed": true,
#             "flush_operations": 0,
#             "unmap_bytes": 0,
#             "wr_bytes": 0,
#             "zone_append_merged": 0,
#             "failed_rd_operations": 0,
#             "invalid_rd_operations": 0,
#             "unmap_operations": 0,
#             "invalid_zone_append_operations": 0,
#             "zone_append_operations": 0,
#             "unmap_merged": 0
#         },
#         "scsi0": {
#             "wr_operations": 393,
#             "rd_merged": 0,
#             "flush_operations": 203,
#             "account_failed": true,
#             "wr_total_time_ns": 796291782,
#             "zone_append_merged": 0,
#             "wr_bytes": 7413760,
#             "unmap_bytes": 0,
#             "zone_append_operations": 0,
#             "invalid_zone_append_operations": 0,
#             "unmap_operations": 0,
#             "failed_rd_operations": 0,
#             "invalid_rd_operations": 0,
#             "unmap_merged": 0,
#             "invalid_unmap_operations": 0,
#             "unmap_total_time_ns": 0,
#             "timed_stats": [],
#             "invalid_flush_operations": 0,
#             "zone_append_bytes": 0,
#             "failed_unmap_operations": 0,
#             "idle_time_ns": 30909004691,
#             "failed_wr_operations": 0,
#             "failed_zone_append_operations": 0,
#             "wr_highest_offset": 38412140544,
#             "rd_total_time_ns": 1924141995,
#             "account_invalid": true,
#             "failed_flush_operations": 0,
#             "zone_append_total_time_ns": 0,
#             "rd_bytes": 422705152,
#             "rd_operations": 11386,
#             "flush_total_time_ns": 242129021,
#             "invalid_wr_operations": 0,
#             "wr_merged": 0
#         }
#     },
#     "agent": 1,
#     "balloon": 4294967296,
#     "ballooninfo": {
#         "total_mem": 3797356544,
#         "actual": 4294967296,
#         "max_mem": 4294967296,
#         "last_update": 1739546566,
#         "free_mem": 3198337024,
#         "mem_swapped_out": 0,
#         "minor_page_faults": 453785,
#         "mem_swapped_in": 0,
#         "major_page_faults": 969
#     },
#     "ha": {
#         "managed": 0
#     },
#     "mem": 599019520,
#     "netin": 1233391,
#     "diskwrite": 7413760,
#     "nics": {
#         "tap100i0": {
#             "netout": 137727,
#             "netin": 1233391
#         }
#     },
#     "maxdisk": 48318382080,
#     "diskread": 424892680
# }
# ✅ Successfully retrieved VM usage stats!
# ✅ Using node: proxmox
# ✅ API Response: {
#     "ha": {
#         "managed": 0
#     },
#     "mem": 599019520,
#     "balloon": 4294967296,
#     "ballooninfo": {
#         "actual": 4294967296,
#         "total_mem": 3797356544,
#         "last_update": 1739546566,
#         "max_mem": 4294967296,
#         "free_mem": 3198337024,
#         "mem_swapped_out": 0,
#         "mem_swapped_in": 0,
#         "minor_page_faults": 453785,
#         "major_page_faults": 969
#     },
#     "agent": 1,
#     "blockstat": {
#         "scsi0": {
#             "failed_zone_append_operations": 0,
#             "wr_highest_offset": 38412140544,
#             "account_invalid": true,
#             "rd_total_time_ns": 1924141995,
#             "failed_flush_operations": 0,
#             "zone_append_total_time_ns": 0,
#             "rd_bytes": 422705152,
#             "rd_operations": 11386,
#             "flush_total_time_ns": 242129021,
#             "invalid_wr_operations": 0,
#             "wr_merged": 0,
#             "invalid_unmap_operations": 0,
#             "unmap_total_time_ns": 0,
#             "timed_stats": [],
#             "invalid_flush_operations": 0,
#             "zone_append_bytes": 0,
#             "failed_unmap_operations": 0,
#             "idle_time_ns": 31192606010,
#             "failed_wr_operations": 0,
#             "zone_append_operations": 0,
#             "unmap_operations": 0,
#             "invalid_zone_append_operations": 0,
#             "invalid_rd_operations": 0,
#             "failed_rd_operations": 0,
#             "unmap_merged": 0,
#             "wr_operations": 393,
#             "rd_merged": 0,
#             "flush_operations": 203,
#             "wr_total_time_ns": 796291782,
#             "account_failed": true,
#             "zone_append_merged": 0,
#             "wr_bytes": 7413760,
#             "unmap_bytes": 0
#         },
#         "efidisk0": {
#             "rd_merged": 0,
#             "wr_operations": 0,
#             "wr_bytes": 0,
#             "zone_append_merged": 0,
#             "unmap_bytes": 0,
#             "wr_total_time_ns": 0,
#             "account_failed": true,
#             "flush_operations": 0,
#             "unmap_operations": 0,
#             "invalid_zone_append_operations": 0,
#             "zone_append_operations": 0,
#             "failed_rd_operations": 0,
#             "invalid_rd_operations": 0,
#             "unmap_merged": 0,
#             "timed_stats": [],
#             "unmap_total_time_ns": 0,
#             "invalid_unmap_operations": 0,
#             "failed_wr_operations": 0,
#             "zone_append_bytes": 0,
#             "invalid_flush_operations": 0,
#             "failed_unmap_operations": 0,
#             "zone_append_total_time_ns": 0,
#             "failed_flush_operations": 0,
#             "rd_bytes": 0,
#             "wr_highest_offset": 49152,
#             "failed_zone_append_operations": 0,
#             "account_invalid": true,
#             "rd_total_time_ns": 0,
#             "invalid_wr_operations": 0,
#             "flush_total_time_ns": 0,
#             "wr_merged": 0,
#             "rd_operations": 0
#         },
#         "ide2": {
#             "invalid_rd_operations": 0,
#             "failed_rd_operations": 0,
#             "zone_append_operations": 0,
#             "invalid_zone_append_operations": 0,
#             "unmap_operations": 0,
#             "unmap_merged": 0,
#             "rd_merged": 0,
#             "wr_operations": 0,
#             "unmap_bytes": 0,
#             "zone_append_merged": 0,
#             "wr_bytes": 0,
#             "flush_operations": 0,
#             "wr_total_time_ns": 0,
#             "account_failed": true,
#             "rd_bytes": 2187528,
#             "failed_flush_operations": 0,
#             "zone_append_total_time_ns": 0,
#             "account_invalid": true,
#             "rd_total_time_ns": 3211717,
#             "failed_zone_append_operations": 0,
#             "wr_highest_offset": 0,
#             "wr_merged": 0,
#             "flush_total_time_ns": 0,
#             "invalid_wr_operations": 0,
#             "rd_operations": 86,
#             "timed_stats": [],
#             "unmap_total_time_ns": 0,
#             "invalid_unmap_operations": 0,
#             "idle_time_ns": 3353132821123,
#             "failed_wr_operations": 0,
#             "failed_unmap_operations": 0,
#             "invalid_flush_operations": 0,
#             "zone_append_bytes": 0
#         },
#         "pflash0": {
#             "failed_unmap_operations": 0,
#             "zone_append_bytes": 0,
#             "invalid_flush_operations": 0,
#             "failed_wr_operations": 0,
#             "invalid_unmap_operations": 0,
#             "unmap_total_time_ns": 0,
#             "timed_stats": [],
#             "rd_operations": 0,
#             "wr_merged": 0,
#             "flush_total_time_ns": 0,
#             "invalid_wr_operations": 0,
#             "rd_total_time_ns": 0,
#             "account_invalid": true,
#             "failed_zone_append_operations": 0,
#             "wr_highest_offset": 0,
#             "rd_bytes": 0,
#             "failed_flush_operations": 0,
#             "zone_append_total_time_ns": 0,
#             "flush_operations": 0,
#             "wr_total_time_ns": 0,
#             "account_failed": true,
#             "unmap_bytes": 0,
#             "zone_append_merged": 0,
#             "wr_bytes": 0,
#             "wr_operations": 0,
#             "rd_merged": 0,
#             "unmap_merged": 0,
#             "invalid_rd_operations": 0,
#             "failed_rd_operations": 0,
#             "zone_append_operations": 0,
#             "unmap_operations": 0,
#             "invalid_zone_append_operations": 0
#         }
#     },
#     "maxdisk": 48318382080,
#     "diskread": 424892680,
#     "nics": {
#         "tap100i0": {
#             "netout": 137805,
#             "netin": 1233817
#         }
#     },
#     "diskwrite": 7413760,
#     "netin": 1233817,
#     "running-machine": "pc-q35-9.0+pve0",
#     "cpu": 0.00749183798940359,
#     "netout": 137805,
#     "proxmox-support": {
#         "pbs-masterkey": true,
#         "pbs-dirty-bitmap-savevm": true,
#         "pbs-dirty-bitmap-migration": true,
#         "backup-fleecing": true,
#         "pbs-library-version": "1.4.1 (UNKNOWN)",
#         "query-bitmap-info": true,
#         "backup-max-workers": true,
#         "pbs-dirty-bitmap": true
#     },
#     "running-qemu": "9.0.2",
#     "vmid": 100,
#     "name": "rhel8-vm",
#     "serial": 1,
#     "cpus": 2,
#     "freemem": 3198337024,
#     "disk": 0,
#     "maxmem": 4294967296,
#     "qmpstatus": "running",
#     "uptime": 3368,
#     "status": "running",
#     "pid": 104400
# }
# 🔍 VM: rhel8-vm | CPU: 0.75% | RAM: 13.95%
# ✅ API Response: {
#     "ballooninfo": {
#         "mem_swapped_out": 0,
#         "minor_page_faults": 1135200,
#         "mem_swapped_in": 0,
#         "major_page_faults": 1118,
#         "total_mem": 3835736064,
#         "actual": 4294967296,
#         "max_mem": 4294967296,
#         "last_update": 1739546567,
#         "free_mem": 3424755712
#     },
#     "balloon": 4294967296,
#     "mem": 410980352,
#     "ha": {
#         "managed": 0
#     },
#     "blockstat": {
#         "scsi0": {
#             "flush_total_time_ns": 4756928332,
#             "invalid_wr_operations": 0,
#             "wr_merged": 0,
#             "rd_operations": 26514,
#             "failed_flush_operations": 0,
#             "zone_append_total_time_ns": 0,
#             "rd_bytes": 875205120,
#             "failed_zone_append_operations": 0,
#             "wr_highest_offset": 34359738368,
#             "account_invalid": true,
#             "rd_total_time_ns": 4473876492,
#             "idle_time_ns": 10592292222,
#             "failed_wr_operations": 0,
#             "invalid_flush_operations": 0,
#             "zone_append_bytes": 0,
#             "failed_unmap_operations": 0,
#             "unmap_total_time_ns": 143740,
#             "timed_stats": [],
#             "invalid_unmap_operations": 0,
#             "unmap_merged": 0,
#             "zone_append_operations": 0,
#             "invalid_zone_append_operations": 0,
#             "unmap_operations": 29,
#             "invalid_rd_operations": 0,
#             "failed_rd_operations": 0,
#             "zone_append_merged": 0,
#             "wr_bytes": 2561179136,
#             "unmap_bytes": 30916214784,
#             "flush_operations": 5574,
#             "wr_total_time_ns": 23862525173,
#             "account_failed": true,
#             "rd_merged": 0,
#             "wr_operations": 18433
#         },
#         "ide2": {
#             "unmap_merged": 0,
#             "failed_rd_operations": 0,
#             "invalid_rd_operations": 0,
#             "invalid_zone_append_operations": 0,
#             "unmap_operations": 0,
#             "zone_append_operations": 0,
#             "unmap_bytes": 0,
#             "wr_bytes": 0,
#             "zone_append_merged": 0,
#             "wr_total_time_ns": 0,
#             "account_failed": true,
#             "flush_operations": 0,
#             "rd_merged": 0,
#             "wr_operations": 0,
#             "wr_merged": 0,
#             "invalid_wr_operations": 0,
#             "flush_total_time_ns": 0,
#             "rd_operations": 8797,
#             "rd_bytes": 492252018,
#             "zone_append_total_time_ns": 0,
#             "failed_flush_operations": 0,
#             "rd_total_time_ns": 539509867,
#             "account_invalid": true,
#             "wr_highest_offset": 0,
#             "failed_zone_append_operations": 0,
#             "failed_wr_operations": 0,
#             "idle_time_ns": 402485913737,
#             "failed_unmap_operations": 0,
#             "zone_append_bytes": 0,
#             "invalid_flush_operations": 0,
#             "timed_stats": [],
#             "unmap_total_time_ns": 0,
#             "invalid_unmap_operations": 0
#         }
#     },
#     "agent": 1,
#     "diskread": 1367457138,
#     "maxdisk": 34359738368,
#     "netin": 905110831,
#     "diskwrite": 2561179136,
#     "nics": {
#         "tap101i0": {
#             "netin": 905110831,
#             "netout": 18561374
#         }
#     },
#     "running-machine": "pc-q35-9.0+pve0",
#     "proxmox-support": {
#         "pbs-dirty-bitmap-migration": true,
#         "pbs-library-version": "1.4.1 (UNKNOWN)",
#         "backup-fleecing": true,
#         "pbs-masterkey": true,
#         "pbs-dirty-bitmap-savevm": true,
#         "backup-max-workers": true,
#         "pbs-dirty-bitmap": true,
#         "query-bitmap-info": true
#     },
#     "netout": 18561374,
#     "cpu": 0.0036476057834705,
#     "name": "rhel8-vm2",
#     "vmid": 101,
#     "running-qemu": "9.0.2",
#     "cpus": 4,
#     "disk": 0,
#     "freemem": 3424755712,
#     "maxmem": 4294967296,
#     "qmpstatus": "running",
#     "pid": 110676,
#     "status": "running",
#     "uptime": 1046
# }
# 🔍 VM: rhel8-vm2 | CPU: 0.36% | RAM: 9.57%
# ✅ Scaling check complete.

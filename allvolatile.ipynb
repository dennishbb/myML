# %%
import pandas as pd
import psycopg2
from psycopg2.extras import execute_values
from datetime import datetime
import numpy as np


# Database configuration
DB_URL = "postgresql://user:password@192.168.0.34:5432/rag_db"
TABLE_NAME = "all_market_data"
OUTPUT_CSV = "market_data.csv"

# Ensure database table exists
def ensure_table_exists():
    try:
        connection = psycopg2.connect(DB_URL)
        cursor = connection.cursor()
        create_table_query = f"""
        CREATE TABLE IF NOT EXISTS {TABLE_NAME} (
            date DATE,
            open NUMERIC,
            high NUMERIC,
            low NUMERIC,
            close NUMERIC,
            adj_close NUMERIC,
            volume BIGINT,
            ticker VARCHAR(20)
        )
        """
        cursor.execute(create_table_query)
        connection.commit()
        cursor.close()
        connection.close()
        print(f"Table {TABLE_NAME} ensured to exist.")
    except Exception as e:
        print(f"Error ensuring table exists: {e}")

# Function to fetch data from yfinance
def fetch_data(ticker):
    print(f"Fetching data for {ticker}...")
    try:
        # Fetch market data
        market_data = yf.download(ticker, period="2d", progress=False)
        market_data.reset_index(inplace=True)
        market_data["Ticker"] = ticker

        # Check and handle the 'Adj Close' column
        if "Adj Close" not in market_data.columns:
            market_data["Adj Close"] = market_data["Close"]

        # Ensure only the required columns exist
        market_data = market_data[["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume", "Ticker"]]
        print(f"Data for {ticker} fetched successfully.")
        return market_data
    except Exception as e:
        print(f"Error fetching data for {ticker}: {e}")
        return pd.DataFrame()

# Save data to a CSV file
def save_to_csv(dataframes):
    try:
        full_data = pd.concat(dataframes, ignore_index=True)
        full_data.to_csv(OUTPUT_CSV, index=False)
        print(f"Data saved to {OUTPUT_CSV}")
    except Exception as e:
        print(f"Error saving to CSV: {e}")

# Save data to PostgreSQL
def save_to_database(dataframes):
    try:
        connection = psycopg2.connect(DB_URL)
        cursor = connection.cursor()

        for df in dataframes:
            # Convert 'Date' column to Python datetime.date
            df['Date'] = pd.to_datetime(df['Date']).dt.date

            # Convert all numeric columns to native Python types
            for col in df.select_dtypes(include=['number']).columns:
                df[col] = df[col].astype(object)

            # Convert DataFrame to records for insertion
            records = df.to_records(index=False)

            # Insert data into PostgreSQL
            execute_values(
                cursor,
                f"""
                INSERT INTO {TABLE_NAME} (date, open, high, low, close, adj_close, volume, ticker)
                VALUES %s
                """,
                records
            )

        connection.commit()
        cursor.close()
        connection.close()
        print(f"Data saved to database table {TABLE_NAME}")
    except Exception as e:
        print(f"Error saving to database: {e}")





# Main function to fetch and save market data
def main():
    ensure_table_exists()

    # Replace with S&P 500 stocks and popular cryptocurrency tickers
    stock_tickers = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]['Symbol'].tolist()
    #crypto_tickers = ['BTC-USD', 'ETH-USD', 'ADA-USD', 'DOGE-USD', 'SOL-USD']  # Example crypto tickers
    crypto_tickers = [
    'BTC-USD', 'ETH-USD', 'ADA-USD', 'DOGE-USD', 'SOL-USD', 'XRP-USD', 
    'LTC-USD', 'DOT-USD', 'BNB-USD', 'MATIC-USD', 'LINK-USD', 'AVAX-USD',
    'SHIB-USD', 'UNI-USD', 'XLM-USD', 'TRX-USD', 'FTT-USD', 'NEAR-USD'
]

    all_tickers = stock_tickers + crypto_tickers

    dataframes = []

    for ticker in all_tickers:
        df = fetch_data(ticker)
        if not df.empty:
            dataframes.append(df)

    if dataframes:
        save_to_csv(dataframes)
        save_to_database(dataframes)
        print("All data fetched, saved to CSV, and stored in the database successfully.")
    else:
        print("No data fetched. Exiting.")

if __name__ == "__main__":
    main()
# Out:
# Table all_market_data ensured to exist.
# Fetching S&P 500 tickers...
# Fetched 503 S&P 500 tickers.
# Fetching cryptocurrency tickers...
# Error fetching cryptocurrency tickers: string indices must be integers, not 'str'
# Fetching data for MMM...
# Data for MMM fetched successfully.
# Fetching data for AOS...
# Data for AOS fetched successfully.
# Fetching data for ABT...
# Data for ABT fetched successfully.
# Fetching data for ABBV...
# Data for ABBV fetched successfully.
# Fetching data for ACN...
# Data for ACN fetched successfully.
# Fetching data for ADBE...
# Data for ADBE fetched successfully.
# Fetching data for AMD...
# Data for AMD fetched successfully.
# Fetching data for AES...
# Data for AES fetched successfully.
# Fetching data for AFL...
# Data for AFL fetched successfully.
# Fetching data for A...
# Data for A fetched successfully.
# Fetching data for APD...
# Data for APD fetched successfully.
# Fetching data for ABNB...
# Data for ABNB fetched successfully.
# Fetching data for AKAM...
# Data for AKAM fetched successfully.
# Fetching data for ALB...
# Data for ALB fetched successfully.
# Fetching data for ARE...
# Data for ARE fetched successfully.
# Fetching data for ALGN...
# Data for ALGN fetched successfully.
# Fetching data for ALLE...
# Data for ALLE fetched successfully.
# Fetching data for LNT...
# Data for LNT fetched successfully.
# Fetching data for ALL...
# Data for ALL fetched successfully.
# Fetching data for GOOGL...
# Data for GOOGL fetched successfully.
# Fetching data for GOOG...
# Data for GOOG fetched successfully.
# Fetching data for MO...
# Data for MO fetched successfully.
# Fetching data for AMZN...
# Data for AMZN fetched successfully.
# Fetching data for AMCR...
# Data for AMCR fetched successfully.
# Fetching data for AEE...
# Data for AEE fetched successfully.
# Fetching data for AEP...
# Data for AEP fetched successfully.
# Fetching data for AXP...
# Data for AXP fetched successfully.
# Fetching data for AIG...
# Data for AIG fetched successfully.
# Fetching data for AMT...
# Data for AMT fetched successfully.
# Fetching data for AWK...
# Data for AWK fetched successfully.
# Fetching data for AMP...
# Data for AMP fetched successfully.
# Fetching data for AME...
# Data for AME fetched successfully.
# Fetching data for AMGN...
# Data for AMGN fetched successfully.
# Fetching data for APH...
# Data for APH fetched successfully.
# Fetching data for ADI...
# Data for ADI fetched successfully.
# Fetching data for ANSS...
# Data for ANSS fetched successfully.
# Fetching data for AON...
# Data for AON fetched successfully.
# Fetching data for APA...
# Data for APA fetched successfully.
# Fetching data for APO...
# Data for APO fetched successfully.
# Fetching data for AAPL...
# Data for AAPL fetched successfully.
# Fetching data for AMAT...
# Data for AMAT fetched successfully.
# Fetching data for APTV...
# Data for APTV fetched successfully.
# Fetching data for ACGL...
# Data for ACGL fetched successfully.
# Fetching data for ADM...
# Data for ADM fetched successfully.
# Fetching data for ANET...
# Data for ANET fetched successfully.
# Fetching data for AJG...
# Data for AJG fetched successfully.
# Fetching data for AIZ...
# Data for AIZ fetched successfully.
# Fetching data for T...
# Data for T fetched successfully.
# Fetching data for ATO...
# Data for ATO fetched successfully.
# Fetching data for ADSK...
# Data for ADSK fetched successfully.
# Fetching data for ADP...
# Data for ADP fetched successfully.
# Fetching data for AZO...
# Data for AZO fetched successfully.
# Fetching data for AVB...
# Data for AVB fetched successfully.
# Fetching data for AVY...
# Data for AVY fetched successfully.
# Fetching data for AXON...
# Data for AXON fetched successfully.
# Fetching data for BKR...
# Data for BKR fetched successfully.
# Fetching data for BALL...
# Data for BALL fetched successfully.
# Fetching data for BAC...
# Data for BAC fetched successfully.
# Fetching data for BAX...
# Data for BAX fetched successfully.
# Fetching data for BDX...
# Data for BDX fetched successfully.
# Fetching data for BRK.B...
# 1 Failed download:
# ['BRK.B']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (period=2d) (Yahoo error = "No data found, symbol may be delisted")')
# Data for BRK.B fetched successfully.
# Fetching data for BBY...
# Data for BBY fetched successfully.
# Fetching data for TECH...
# Data for TECH fetched successfully.
# Fetching data for BIIB...
# Data for BIIB fetched successfully.
# Fetching data for BLK...
# Data for BLK fetched successfully.
# Fetching data for BX...
# Data for BX fetched successfully.
# Fetching data for BK...
# Data for BK fetched successfully.
# Fetching data for BA...
# Data for BA fetched successfully.
# Fetching data for BKNG...
# Data for BKNG fetched successfully.
# Fetching data for BWA...
# Data for BWA fetched successfully.
# Fetching data for BSX...
# Data for BSX fetched successfully.
# Fetching data for BMY...
# Data for BMY fetched successfully.
# Fetching data for AVGO...
# Data for AVGO fetched successfully.
# Fetching data for BR...
# Data for BR fetched successfully.
# Fetching data for BRO...
# Data for BRO fetched successfully.
# Fetching data for BF.B...
# 1 Failed download:
# ['BF.B']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (period=2d)')
# Data for BF.B fetched successfully.
# Fetching data for BLDR...
# Data for BLDR fetched successfully.
# Fetching data for BG...
# Data for BG fetched successfully.
# Fetching data for BXP...
# Data for BXP fetched successfully.
# Fetching data for CHRW...
# Data for CHRW fetched successfully.
# Fetching data for CDNS...
# Data for CDNS fetched successfully.
# Fetching data for CZR...
# Data for CZR fetched successfully.
# Fetching data for CPT...
# Data for CPT fetched successfully.
# Fetching data for CPB...
# Data for CPB fetched successfully.
# Fetching data for COF...
# Data for COF fetched successfully.
# Fetching data for CAH...
# Data for CAH fetched successfully.
# Fetching data for KMX...
# Data for KMX fetched successfully.
# Fetching data for CCL...
# Data for CCL fetched successfully.
# Fetching data for CARR...
# Data for CARR fetched successfully.
# Fetching data for CAT...
# Data for CAT fetched successfully.
# Fetching data for CBOE...
# Data for CBOE fetched successfully.
# Fetching data for CBRE...
# Data for CBRE fetched successfully.
# Fetching data for CDW...
# Data for CDW fetched successfully.
# Fetching data for CE...
# Data for CE fetched successfully.
# Fetching data for COR...
# Data for COR fetched successfully.
# Fetching data for CNC...
# Data for CNC fetched successfully.
# Fetching data for CNP...
# Data for CNP fetched successfully.
# Fetching data for CF...
# Data for CF fetched successfully.
# Fetching data for CRL...
# Data for CRL fetched successfully.
# Fetching data for SCHW...
# Data for SCHW fetched successfully.
# Fetching data for CHTR...
# Data for CHTR fetched successfully.
# Fetching data for CVX...
# Data for CVX fetched successfully.
# Fetching data for CMG...
# Data for CMG fetched successfully.
# Fetching data for CB...
# Data for CB fetched successfully.
# Fetching data for CHD...
# Data for CHD fetched successfully.
# Fetching data for CI...
# Data for CI fetched successfully.
# Fetching data for CINF...
# Data for CINF fetched successfully.
# Fetching data for CTAS...
# Data for CTAS fetched successfully.
# Fetching data for CSCO...
# Data for CSCO fetched successfully.
# Fetching data for C...
# Data for C fetched successfully.
# Fetching data for CFG...
# Data for CFG fetched successfully.
# Fetching data for CLX...
# Data for CLX fetched successfully.
# Fetching data for CME...
# Data for CME fetched successfully.
# Fetching data for CMS...
# Data for CMS fetched successfully.
# Fetching data for KO...
# Data for KO fetched successfully.
# Fetching data for CTSH...
# Data for CTSH fetched successfully.
# Fetching data for CL...
# Data for CL fetched successfully.
# Fetching data for CMCSA...
# Data for CMCSA fetched successfully.
# Fetching data for CAG...
# Data for CAG fetched successfully.
# Fetching data for COP...
# Data for COP fetched successfully.
# Fetching data for ED...
# Data for ED fetched successfully.
# Fetching data for STZ...
# Data for STZ fetched successfully.
# Fetching data for CEG...
# Data for CEG fetched successfully.
# Fetching data for COO...
# Data for COO fetched successfully.
# Fetching data for CPRT...
# Data for CPRT fetched successfully.
# Fetching data for GLW...
# Data for GLW fetched successfully.
# Fetching data for CPAY...
# Data for CPAY fetched successfully.
# Fetching data for CTVA...
# Data for CTVA fetched successfully.
# Fetching data for CSGP...
# Data for CSGP fetched successfully.
# Fetching data for COST...
# Data for COST fetched successfully.
# Fetching data for CTRA...
# Data for CTRA fetched successfully.
# Fetching data for CRWD...
# Data for CRWD fetched successfully.
# Fetching data for CCI...
# Data for CCI fetched successfully.
# Fetching data for CSX...
# Data for CSX fetched successfully.
# Fetching data for CMI...
# Data for CMI fetched successfully.
# Fetching data for CVS...
# Data for CVS fetched successfully.
# Fetching data for DHR...
# Data for DHR fetched successfully.
# Fetching data for DRI...
# Data for DRI fetched successfully.
# Fetching data for DVA...
# Data for DVA fetched successfully.
# Fetching data for DAY...
# Data for DAY fetched successfully.
# Fetching data for DECK...
# Data for DECK fetched successfully.
# Fetching data for DE...
# Data for DE fetched successfully.
# Fetching data for DELL...
# Data for DELL fetched successfully.
# Fetching data for DAL...
# Data for DAL fetched successfully.
# Fetching data for DVN...
# Data for DVN fetched successfully.
# Fetching data for DXCM...
# Data for DXCM fetched successfully.
# Fetching data for FANG...
# Data for FANG fetched successfully.
# Fetching data for DLR...
# Data for DLR fetched successfully.
# Fetching data for DFS...
# Data for DFS fetched successfully.
# Fetching data for DG...
# Data for DG fetched successfully.
# Fetching data for DLTR...
# Data for DLTR fetched successfully.
# Fetching data for D...
# Data for D fetched successfully.
# Fetching data for DPZ...
# Data for DPZ fetched successfully.
# Fetching data for DOV...
# Data for DOV fetched successfully.
# Fetching data for DOW...
# Data for DOW fetched successfully.
# Fetching data for DHI...
# Data for DHI fetched successfully.
# Fetching data for DTE...
# Data for DTE fetched successfully.
# Fetching data for DUK...
# Data for DUK fetched successfully.
# Fetching data for DD...
# Data for DD fetched successfully.
# Fetching data for EMN...
# Data for EMN fetched successfully.
# Fetching data for ETN...
# Data for ETN fetched successfully.
# Fetching data for EBAY...
# Data for EBAY fetched successfully.
# Fetching data for ECL...
# Data for ECL fetched successfully.
# Fetching data for EIX...
# Data for EIX fetched successfully.
# Fetching data for EW...
# Data for EW fetched successfully.
# Fetching data for EA...
# Data for EA fetched successfully.
# Fetching data for ELV...
# Data for ELV fetched successfully.
# Fetching data for EMR...
# Data for EMR fetched successfully.
# Fetching data for ENPH...
# Data for ENPH fetched successfully.
# Fetching data for ETR...
# Data for ETR fetched successfully.
# Fetching data for EOG...
# Data for EOG fetched successfully.
# Fetching data for EPAM...
# Data for EPAM fetched successfully.
# Fetching data for EQT...
# Data for EQT fetched successfully.
# Fetching data for EFX...
# Data for EFX fetched successfully.
# Fetching data for EQIX...
# Data for EQIX fetched successfully.
# Fetching data for EQR...
# Data for EQR fetched successfully.
# Fetching data for ERIE...
# Data for ERIE fetched successfully.
# Fetching data for ESS...
# Data for ESS fetched successfully.
# Fetching data for EL...
# Data for EL fetched successfully.
# Fetching data for EG...
# Data for EG fetched successfully.
# Fetching data for EVRG...
# Data for EVRG fetched successfully.
# Fetching data for ES...
# Data for ES fetched successfully.
# Fetching data for EXC...
# Data for EXC fetched successfully.
# Fetching data for EXPE...
# Data for EXPE fetched successfully.
# Fetching data for EXPD...
# Data for EXPD fetched successfully.
# Fetching data for EXR...
# Data for EXR fetched successfully.
# Fetching data for XOM...
# Data for XOM fetched successfully.
# Fetching data for FFIV...
# Data for FFIV fetched successfully.
# Fetching data for FDS...
# Data for FDS fetched successfully.
# Fetching data for FICO...
# Data for FICO fetched successfully.
# Fetching data for FAST...
# Data for FAST fetched successfully.
# Fetching data for FRT...
# Data for FRT fetched successfully.
# Fetching data for FDX...
# Data for FDX fetched successfully.
# Fetching data for FIS...
# Data for FIS fetched successfully.
# Fetching data for FITB...
# Data for FITB fetched successfully.
# Fetching data for FSLR...
# Data for FSLR fetched successfully.
# Fetching data for FE...
# Data for FE fetched successfully.
# Fetching data for FI...
# Data for FI fetched successfully.
# Fetching data for FMC...
# Data for FMC fetched successfully.
# Fetching data for F...
# Data for F fetched successfully.
# Fetching data for FTNT...
# Data for FTNT fetched successfully.
# Fetching data for FTV...
# Data for FTV fetched successfully.
# Fetching data for FOXA...
# Data for FOXA fetched successfully.
# Fetching data for FOX...
# Data for FOX fetched successfully.
# Fetching data for BEN...
# Data for BEN fetched successfully.
# Fetching data for FCX...
# Data for FCX fetched successfully.
# Fetching data for GRMN...
# Data for GRMN fetched successfully.
# Fetching data for IT...
# Data for IT fetched successfully.
# Fetching data for GE...
# Data for GE fetched successfully.
# Fetching data for GEHC...
# Data for GEHC fetched successfully.
# Fetching data for GEV...
# Data for GEV fetched successfully.
# Fetching data for GEN...
# Data for GEN fetched successfully.
# Fetching data for GNRC...
# Data for GNRC fetched successfully.
# Fetching data for GD...
# Data for GD fetched successfully.
# Fetching data for GIS...
# Data for GIS fetched successfully.
# Fetching data for GM...
# Data for GM fetched successfully.
# Fetching data for GPC...
# Data for GPC fetched successfully.
# Fetching data for GILD...
# Data for GILD fetched successfully.
# Fetching data for GPN...
# Data for GPN fetched successfully.
# Fetching data for GL...
# Data for GL fetched successfully.
# Fetching data for GDDY...
# Data for GDDY fetched successfully.
# Fetching data for GS...
# Data for GS fetched successfully.
# Fetching data for HAL...
# Data for HAL fetched successfully.
# Fetching data for HIG...
# Data for HIG fetched successfully.
# Fetching data for HAS...
# Data for HAS fetched successfully.
# Fetching data for HCA...
# Data for HCA fetched successfully.
# Fetching data for DOC...
# Data for DOC fetched successfully.
# Fetching data for HSIC...
# Data for HSIC fetched successfully.
# Fetching data for HSY...
# Data for HSY fetched successfully.
# Fetching data for HES...
# Data for HES fetched successfully.
# Fetching data for HPE...
# Data for HPE fetched successfully.
# Fetching data for HLT...
# Data for HLT fetched successfully.
# Fetching data for HOLX...
# Data for HOLX fetched successfully.
# Fetching data for HD...
# Data for HD fetched successfully.
# Fetching data for HON...
# Data for HON fetched successfully.
# Fetching data for HRL...
# Data for HRL fetched successfully.
# Fetching data for HST...
# Data for HST fetched successfully.
# Fetching data for HWM...
# Data for HWM fetched successfully.
# Fetching data for HPQ...
# Data for HPQ fetched successfully.
# Fetching data for HUBB...
# Data for HUBB fetched successfully.
# Fetching data for HUM...
# Data for HUM fetched successfully.
# Fetching data for HBAN...
# Data for HBAN fetched successfully.
# Fetching data for HII...
# Data for HII fetched successfully.
# Fetching data for IBM...
# Data for IBM fetched successfully.
# Fetching data for IEX...
# Data for IEX fetched successfully.
# Fetching data for IDXX...
# Data for IDXX fetched successfully.
# Fetching data for ITW...
# Data for ITW fetched successfully.
# Fetching data for INCY...
# Data for INCY fetched successfully.
# Fetching data for IR...
# Data for IR fetched successfully.
# Fetching data for PODD...
# Data for PODD fetched successfully.
# Fetching data for INTC...
# Data for INTC fetched successfully.
# Fetching data for ICE...
# Data for ICE fetched successfully.
# Fetching data for IFF...
# Data for IFF fetched successfully.
# Fetching data for IP...
# Data for IP fetched successfully.
# Fetching data for IPG...
# Data for IPG fetched successfully.
# Fetching data for INTU...
# Data for INTU fetched successfully.
# Fetching data for ISRG...
# Data for ISRG fetched successfully.
# Fetching data for IVZ...
# Data for IVZ fetched successfully.
# Fetching data for INVH...
# Data for INVH fetched successfully.
# Fetching data for IQV...
# Data for IQV fetched successfully.
# Fetching data for IRM...
# Data for IRM fetched successfully.
# Fetching data for JBHT...
# Data for JBHT fetched successfully.
# Fetching data for JBL...
# Data for JBL fetched successfully.
# Fetching data for JKHY...
# Data for JKHY fetched successfully.
# Fetching data for J...
# Data for J fetched successfully.
# Fetching data for JNJ...
# Data for JNJ fetched successfully.
# Fetching data for JCI...
# Data for JCI fetched successfully.
# Fetching data for JPM...
# Data for JPM fetched successfully.
# Fetching data for JNPR...
# Data for JNPR fetched successfully.
# Fetching data for K...
# Data for K fetched successfully.
# Fetching data for KVUE...
# Data for KVUE fetched successfully.
# Fetching data for KDP...
# Data for KDP fetched successfully.
# Fetching data for KEY...
# Data for KEY fetched successfully.
# Fetching data for KEYS...
# Data for KEYS fetched successfully.
# Fetching data for KMB...
# Data for KMB fetched successfully.
# Fetching data for KIM...
# Data for KIM fetched successfully.
# Fetching data for KMI...
# Data for KMI fetched successfully.
# Fetching data for KKR...
# Data for KKR fetched successfully.
# Fetching data for KLAC...
# Data for KLAC fetched successfully.
# Fetching data for KHC...
# Data for KHC fetched successfully.
# Fetching data for KR...
# Data for KR fetched successfully.
# Fetching data for LHX...
# Data for LHX fetched successfully.
# Fetching data for LH...
# Data for LH fetched successfully.
# Fetching data for LRCX...
# Data for LRCX fetched successfully.
# Fetching data for LW...
# Data for LW fetched successfully.
# Fetching data for LVS...
# Data for LVS fetched successfully.
# Fetching data for LDOS...
# Data for LDOS fetched successfully.
# Fetching data for LEN...
# Data for LEN fetched successfully.
# Fetching data for LII...
# Data for LII fetched successfully.
# Fetching data for LLY...
# Data for LLY fetched successfully.
# Fetching data for LIN...
# Data for LIN fetched successfully.
# Fetching data for LYV...
# Data for LYV fetched successfully.
# Fetching data for LKQ...
# Data for LKQ fetched successfully.
# Fetching data for LMT...
# Data for LMT fetched successfully.
# Fetching data for L...
# Data for L fetched successfully.
# Fetching data for LOW...
# Data for LOW fetched successfully.
# Fetching data for LULU...
# Data for LULU fetched successfully.
# Fetching data for LYB...
# Data for LYB fetched successfully.
# Fetching data for MTB...
# Data for MTB fetched successfully.
# Fetching data for MPC...
# Data for MPC fetched successfully.
# Fetching data for MKTX...
# Data for MKTX fetched successfully.
# Fetching data for MAR...
# Data for MAR fetched successfully.
# Fetching data for MMC...
# Data for MMC fetched successfully.
# Fetching data for MLM...
# Data for MLM fetched successfully.
# Fetching data for MAS...
# Data for MAS fetched successfully.
# Fetching data for MA...
# Data for MA fetched successfully.
# Fetching data for MTCH...
# Data for MTCH fetched successfully.
# Fetching data for MKC...
# Data for MKC fetched successfully.
# Fetching data for MCD...
# Data for MCD fetched successfully.
# Fetching data for MCK...
# Data for MCK fetched successfully.
# Fetching data for MDT...
# Data for MDT fetched successfully.
# Fetching data for MRK...
# Data for MRK fetched successfully.
# Fetching data for META...
# Data for META fetched successfully.
# Fetching data for MET...
# Data for MET fetched successfully.
# Fetching data for MTD...
# Data for MTD fetched successfully.
# Fetching data for MGM...
# Data for MGM fetched successfully.
# Fetching data for MCHP...
# Data for MCHP fetched successfully.
# Fetching data for MU...
# Data for MU fetched successfully.
# Fetching data for MSFT...
# Data for MSFT fetched successfully.
# Fetching data for MAA...
# Data for MAA fetched successfully.
# Fetching data for MRNA...
# Data for MRNA fetched successfully.
# Fetching data for MHK...
# Data for MHK fetched successfully.
# Fetching data for MOH...
# Data for MOH fetched successfully.
# Fetching data for TAP...
# Data for TAP fetched successfully.
# Fetching data for MDLZ...
# Data for MDLZ fetched successfully.
# Fetching data for MPWR...
# Data for MPWR fetched successfully.
# Fetching data for MNST...
# Data for MNST fetched successfully.
# Fetching data for MCO...
# Data for MCO fetched successfully.
# Fetching data for MS...
# Data for MS fetched successfully.
# Fetching data for MOS...
# Data for MOS fetched successfully.
# Fetching data for MSI...
# Data for MSI fetched successfully.
# Fetching data for MSCI...
# Data for MSCI fetched successfully.
# Fetching data for NDAQ...
# Data for NDAQ fetched successfully.
# Fetching data for NTAP...
# Data for NTAP fetched successfully.
# Fetching data for NFLX...
# Data for NFLX fetched successfully.
# Fetching data for NEM...
# Data for NEM fetched successfully.
# Fetching data for NWSA...
# Data for NWSA fetched successfully.
# Fetching data for NWS...
# Data for NWS fetched successfully.
# Fetching data for NEE...
# Data for NEE fetched successfully.
# Fetching data for NKE...
# Data for NKE fetched successfully.
# Fetching data for NI...
# Data for NI fetched successfully.
# Fetching data for NDSN...
# Data for NDSN fetched successfully.
# Fetching data for NSC...
# Data for NSC fetched successfully.
# Fetching data for NTRS...
# Data for NTRS fetched successfully.
# Fetching data for NOC...
# Data for NOC fetched successfully.
# Fetching data for NCLH...
# Data for NCLH fetched successfully.
# Fetching data for NRG...
# Data for NRG fetched successfully.
# Fetching data for NUE...
# Data for NUE fetched successfully.
# Fetching data for NVDA...
# Data for NVDA fetched successfully.
# Fetching data for NVR...
# Data for NVR fetched successfully.
# Fetching data for NXPI...
# Data for NXPI fetched successfully.
# Fetching data for ORLY...
# Data for ORLY fetched successfully.
# Fetching data for OXY...
# Data for OXY fetched successfully.
# Fetching data for ODFL...
# Data for ODFL fetched successfully.
# Fetching data for OMC...
# Data for OMC fetched successfully.
# Fetching data for ON...
# Data for ON fetched successfully.
# Fetching data for OKE...
# Data for OKE fetched successfully.
# Fetching data for ORCL...
# Data for ORCL fetched successfully.
# Fetching data for OTIS...
# Data for OTIS fetched successfully.
# Fetching data for PCAR...
# Data for PCAR fetched successfully.
# Fetching data for PKG...
# Data for PKG fetched successfully.
# Fetching data for PLTR...
# Data for PLTR fetched successfully.
# Fetching data for PANW...
# Data for PANW fetched successfully.
# Fetching data for PARA...
# Data for PARA fetched successfully.
# Fetching data for PH...
# Data for PH fetched successfully.
# Fetching data for PAYX...
# Data for PAYX fetched successfully.
# Fetching data for PAYC...
# Data for PAYC fetched successfully.
# Fetching data for PYPL...
# Data for PYPL fetched successfully.
# Fetching data for PNR...
# Data for PNR fetched successfully.
# Fetching data for PEP...
# Data for PEP fetched successfully.
# Fetching data for PFE...
# Data for PFE fetched successfully.
# Fetching data for PCG...
# Data for PCG fetched successfully.
# Fetching data for PM...
# Data for PM fetched successfully.
# Fetching data for PSX...
# Data for PSX fetched successfully.
# Fetching data for PNW...
# Data for PNW fetched successfully.
# Fetching data for PNC...
# Data for PNC fetched successfully.
# Fetching data for POOL...
# Data for POOL fetched successfully.
# Fetching data for PPG...
# Data for PPG fetched successfully.
# Fetching data for PPL...
# Data for PPL fetched successfully.
# Fetching data for PFG...
# Data for PFG fetched successfully.
# Fetching data for PG...
# Data for PG fetched successfully.
# Fetching data for PGR...
# Data for PGR fetched successfully.
# Fetching data for PLD...
# Data for PLD fetched successfully.
# Fetching data for PRU...
# Data for PRU fetched successfully.
# Fetching data for PEG...
# Data for PEG fetched successfully.
# Fetching data for PTC...
# Data for PTC fetched successfully.
# Fetching data for PSA...
# Data for PSA fetched successfully.
# Fetching data for PHM...
# Data for PHM fetched successfully.
# Fetching data for PWR...
# Data for PWR fetched successfully.
# Fetching data for QCOM...
# Data for QCOM fetched successfully.
# Fetching data for DGX...
# Data for DGX fetched successfully.
# Fetching data for RL...
# Data for RL fetched successfully.
# Fetching data for RJF...
# Data for RJF fetched successfully.
# Fetching data for RTX...
# Data for RTX fetched successfully.
# Fetching data for O...
# Data for O fetched successfully.
# Fetching data for REG...
# Data for REG fetched successfully.
# Fetching data for REGN...
# Data for REGN fetched successfully.
# Fetching data for RF...
# Data for RF fetched successfully.
# Fetching data for RSG...
# Data for RSG fetched successfully.
# Fetching data for RMD...
# Data for RMD fetched successfully.
# Fetching data for RVTY...
# Data for RVTY fetched successfully.
# Fetching data for ROK...
# Data for ROK fetched successfully.
# Fetching data for ROL...
# Data for ROL fetched successfully.
# Fetching data for ROP...
# Data for ROP fetched successfully.
# Fetching data for ROST...
# Data for ROST fetched successfully.
# Fetching data for RCL...
# Data for RCL fetched successfully.
# Fetching data for SPGI...
# Data for SPGI fetched successfully.
# Fetching data for CRM...
# Data for CRM fetched successfully.
# Fetching data for SBAC...
# Data for SBAC fetched successfully.
# Fetching data for SLB...
# Data for SLB fetched successfully.
# Fetching data for STX...
# Data for STX fetched successfully.
# Fetching data for SRE...
# Data for SRE fetched successfully.
# Fetching data for NOW...
# Data for NOW fetched successfully.
# Fetching data for SHW...
# Data for SHW fetched successfully.
# Fetching data for SPG...
# Data for SPG fetched successfully.
# Fetching data for SWKS...
# Data for SWKS fetched successfully.
# Fetching data for SJM...
# Data for SJM fetched successfully.
# Fetching data for SW...
# Data for SW fetched successfully.
# Fetching data for SNA...
# Data for SNA fetched successfully.
# Fetching data for SOLV...
# Data for SOLV fetched successfully.
# Fetching data for SO...
# Data for SO fetched successfully.
# Fetching data for LUV...
# Data for LUV fetched successfully.
# Fetching data for SWK...
# Data for SWK fetched successfully.
# Fetching data for SBUX...
# Data for SBUX fetched successfully.
# Fetching data for STT...
# Data for STT fetched successfully.
# Fetching data for STLD...
# Data for STLD fetched successfully.
# Fetching data for STE...
# Data for STE fetched successfully.
# Fetching data for SYK...
# Data for SYK fetched successfully.
# Fetching data for SMCI...
# Data for SMCI fetched successfully.
# Fetching data for SYF...
# Data for SYF fetched successfully.
# Fetching data for SNPS...
# Data for SNPS fetched successfully.
# Fetching data for SYY...
# Data for SYY fetched successfully.
# Fetching data for TMUS...
# Data for TMUS fetched successfully.
# Fetching data for TROW...
# Data for TROW fetched successfully.
# Fetching data for TTWO...
# Data for TTWO fetched successfully.
# Fetching data for TPR...
# Data for TPR fetched successfully.
# Fetching data for TRGP...
# Data for TRGP fetched successfully.
# Fetching data for TGT...
# Data for TGT fetched successfully.
# Fetching data for TEL...
# Data for TEL fetched successfully.
# Fetching data for TDY...
# Data for TDY fetched successfully.
# Fetching data for TFX...
# Data for TFX fetched successfully.
# Fetching data for TER...
# Data for TER fetched successfully.
# Fetching data for TSLA...
# Data for TSLA fetched successfully.
# Fetching data for TXN...
# Data for TXN fetched successfully.
# Fetching data for TPL...
# Data for TPL fetched successfully.
# Fetching data for TXT...
# Data for TXT fetched successfully.
# Fetching data for TMO...
# Data for TMO fetched successfully.
# Fetching data for TJX...
# Data for TJX fetched successfully.
# Fetching data for TSCO...
# Data for TSCO fetched successfully.
# Fetching data for TT...
# Data for TT fetched successfully.
# Fetching data for TDG...
# Data for TDG fetched successfully.
# Fetching data for TRV...
# Data for TRV fetched successfully.
# Fetching data for TRMB...
# Data for TRMB fetched successfully.
# Fetching data for TFC...
# Data for TFC fetched successfully.
# Fetching data for TYL...
# Data for TYL fetched successfully.
# Fetching data for TSN...
# Data for TSN fetched successfully.
# Fetching data for USB...
# Data for USB fetched successfully.
# Fetching data for UBER...
# Data for UBER fetched successfully.
# Fetching data for UDR...
# Data for UDR fetched successfully.
# Fetching data for ULTA...
# Data for ULTA fetched successfully.
# Fetching data for UNP...
# Data for UNP fetched successfully.
# Fetching data for UAL...
# Data for UAL fetched successfully.
# Fetching data for UPS...
# Data for UPS fetched successfully.
# Fetching data for URI...
# Data for URI fetched successfully.
# Fetching data for UNH...
# Data for UNH fetched successfully.
# Fetching data for UHS...
# Data for UHS fetched successfully.
# Fetching data for VLO...
# Data for VLO fetched successfully.
# Fetching data for VTR...
# Data for VTR fetched successfully.
# Fetching data for VLTO...
# Data for VLTO fetched successfully.
# Fetching data for VRSN...
# Data for VRSN fetched successfully.
# Fetching data for VRSK...
# Data for VRSK fetched successfully.
# Fetching data for VZ...
# Data for VZ fetched successfully.
# Fetching data for VRTX...
# Data for VRTX fetched successfully.
# Fetching data for VTRS...
# Data for VTRS fetched successfully.
# Fetching data for VICI...
# Data for VICI fetched successfully.
# Fetching data for V...
# Data for V fetched successfully.
# Fetching data for VST...
# Data for VST fetched successfully.
# Fetching data for VMC...
# Data for VMC fetched successfully.
# Fetching data for WRB...
# Data for WRB fetched successfully.
# Fetching data for GWW...
# Data for GWW fetched successfully.
# Fetching data for WAB...
# Data for WAB fetched successfully.
# Fetching data for WBA...
# Data for WBA fetched successfully.
# Fetching data for WMT...
# Data for WMT fetched successfully.
# Fetching data for DIS...
# Data for DIS fetched successfully.
# Fetching data for WBD...
# Data for WBD fetched successfully.
# Fetching data for WM...
# Data for WM fetched successfully.
# Fetching data for WAT...
# Data for WAT fetched successfully.
# Fetching data for WEC...
# Data for WEC fetched successfully.
# Fetching data for WFC...
# Data for WFC fetched successfully.
# Fetching data for WELL...
# Data for WELL fetched successfully.
# Fetching data for WST...
# Data for WST fetched successfully.
# Fetching data for WDC...
# Data for WDC fetched successfully.
# Fetching data for WY...
# Data for WY fetched successfully.
# Fetching data for WMB...
# Data for WMB fetched successfully.
# Fetching data for WTW...
# Data for WTW fetched successfully.
# Fetching data for WDAY...
# Data for WDAY fetched successfully.
# Fetching data for WYNN...
# Data for WYNN fetched successfully.
# Fetching data for XEL...
# Data for XEL fetched successfully.
# Fetching data for XYL...
# Data for XYL fetched successfully.
# Fetching data for YUM...
# Data for YUM fetched successfully.
# Fetching data for ZBRA...
# Data for ZBRA fetched successfully.
# Fetching data for ZBH...
# Data for ZBH fetched successfully.
# Fetching data for ZTS...
# Data for ZTS fetched successfully.
# Data saved to market_data.csv
# Data saved to database table all_market_data
# All data fetched, saved to CSV, and stored in the database successfully.
